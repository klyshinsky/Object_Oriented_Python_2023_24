# %% [markdown]
# # Снижение размерности пространства

# %% [markdown]
# Визуализация данных помогает понять их структуру и, как следствие, подсказывает методы анализа этих данных. Однако отображение многомерных данных на плоскости упирается в слишком большое количество измерений. Следовательно, встает задача отображения большого числа измерений на плоскость.
#
# Ниже генерируются данные состоящие из трех четырехмерных сфер, точки в которых распределены нормально. Если мы построим их четырехмерный эпюр, то границу между этими сферами не будет видно.

# %%
from sklearn.datasets import make_blobs

# Интерактивный режим отображения рисунков - масштабирование, перемещение, вращение, ...
#%matplotlib notebook
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
blob_X, y = make_blobs(n_samples=[30, 30, 30], # Хочу три группы по 30 точек.
                       centers=[[-7, -7, -7, -7], # Хочу чтобы центры располагались в этих 4-мерных координатах.
                                [0, 0, 0, 0], 
                                [7, 7, 7, 7]], 
                       cluster_std=2.3, # Хочу дисперсию 2.3
                       random_state=77) # Хочу чтобы каждый раз генерировалась одна и та же картинка.

# %%
# Построение четырехмерного эпюра для сгенерированных данных.
sns.pairplot(pd.DataFrame(blob_X));

# %% [markdown]
# Однако, если подобрать правильную проекцию для отображаемых данных, то сразу станет видно, что сгенерированные сферы не пересекаются (или почти не пересекаются).
#
# ### Метод главных компонент (PCA)
#
# Подберем такую проекцию при помощи <a href="https://habr.com/post/304214/">метода главных компонент</a> (<i>PCA, Principle Component Analysis, <a href="http://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html"> документация</a></i>, можно немного потрогать руками <a href="https://setosa.io/ev/principal-component-analysis/">здесь</a>, с большим количеством математики метод описывается на <a href="http://www.machinelearning.ru/wiki/index.php?title=%D0%9C%D0%B5%D1%82%D0%BE%D0%B4_%D0%B3%D0%BB%D0%B0%D0%B2%D0%BD%D1%8B%D1%85_%D0%BA%D0%BE%D0%BC%D0%BF%D0%BE%D0%BD%D0%B5%D0%BD%D1%82">machinelearning.ru</a>). Метод основывается на применении сингулярного разложения матриц (SVD). Его суть состоит в том, что мы преобразуем пространство в новое, имеющее меньшую размерность, и строим проекцию на него. Для этого находится новая ось, вдоль которой относительная дисперсия наших данных максимальна. Далее строится проекция всех точек на эту ось, а полученные значения становятся первой координатой в новом пространстве. Это направление отбрасывается, после чего можно снова попытаться найти еще одну ось, еще одну и т.д. Операцию можно повторить столько раз, сколько измерений должно быть в новом пространстве.
#
# ![](img/correlated_2d.png)

# %% [markdown]
# По умолчанию PCA строит преставление пространства той же размерности, что и входные данные, однако сортирует измерения по "важности".<br>
# При помощи функции fit_transform мы настраиваем коэффициенты преобразования (fit) и преобразуем переданные точки (transform). Каждое из этих действий для PCA можно производить по отдельности.<br>

# %%
from sklearn.decomposition import PCA

# %%
# Создаем объект для преобразования при помощи PCA, 
# он будет преобразовывать в двумерное пространство.
pca_obj = PCA(n_components=2) 
# Настраиваемся на точки, изменяя систему координат, и одновременно
# преобразуем их координаты в два измерения.
show_reduced = pca_obj.fit_transform(blob_X)
# Рисуем точки в преобразованных координатах.
plt.scatter(x=[d[0] for d in show_reduced], 
            y=[d[1] for d in show_reduced]);
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# Добавим новые точки и сразу преобразуем их в полученное пространство меньшей размерности.

# %% [markdown]
# Плюсом метода PCA является тот факт, что после нахождения осей в новое пространство можно преобразовать любую точку исходного пространства. Это возможно, так как преобразование сводится к повороту, масштабированию и проекции.

# %%
# Генерируем новые точки.
new_points = [(2*i, i, 3*i, i) for i in range(-2, 3)]
# Проецируем их в имеющееся двумерное пространство.
new_2d = pca_obj.transform(new_points)
# Рисуем старые точки.
plt.scatter(x=[d[0] for d in show_reduced], 
                 y=[d[1] for d in show_reduced]);
# Рисуем новые точки.
plt.scatter(x=[d[0] for d in new_2d], 
            y=[d[1] for d in new_2d], 
            c='r');
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# Можно посмотреть куда "смотрят" новые оси в исходном пространстве.

# %%
# Координаты осей в исходном пространстве.
pca_obj.components_
# Out:
# array([[ 0.49230642,  0.50256462,  0.52324478,  0.4809138 ],
#        [-0.73737863,  0.66718989,  0.09504508, -0.04579125]])

# %%
# Насколько данная координата "объясняет" изменение значений.
pca_obj.explained_variance_ratio_
# Out:
# array([0.90363366, 0.0378258 ])

# %% [markdown]
# ### Метод t-SNE
#
# Еще одним методом является t-SNE (<i>t-distributed stochastic neighbor embedding</i>). В отличие от предыдущих двух методов, он не строит проекции, а пытается "вдавить" точки в пространство заданной размерности, соблюдая при этом примерное расположение точек. Очевидно, полностью сохранить расположение получается не всегда, но алгоритм старается сделать так, чтобы соседние точки остались соседними.
#
# Примерно такая же картина в смысле разрывов и искажений наблюдается при применении методов наподобие t-SNE. Для разных начальных расположений точек будет получаться разная картина для искажений. Что-то похожее происходит, когда мы рисуем плоскую карту Земли по трехмерному глобусу. При построении такой проекции мы тоже пытаеммся снизить размерность трехмерной фигуры до двух измерений. При этом могут использоваться искажения, то есть мы будем сжимать и растягивать карту. При этом могут возникать разрывы в разных местах. В любом случае, точки, которые были рядом (например, по границе карты) оказываются разнесены друг от друга.
#
# Следует иметь в виду, что в зависимости от того, какую мы выбираем начальную инициализацию, результат может отличаться.
#
# <img src="img/scale_1200.webp" width="400">
# <img src="img/675px-Goode_homolosine_projection_SW.jpg" width="400">
# <img src="img/0c41ef6a88a84deaaccf18ae2a5862cd.jpg" width="400">
# <img src="img/728x728_1_c8e398fc8b09167c72d137f7a7fed660@798x798_0xac120003_3215217821597054271.jpg" width="400">
# Больше примеров проекций см. <a href = "https://xkcd.com/977/">здесь</a>.

# %%
from sklearn.manifold import TSNE

# %%
tsne=TSNE()
show_reduced = tsne.fit_transform(blob_X)

fig, ax = plt.subplots()
ax.scatter(show_reduced[:, 0], show_reduced[:, 1], 
           cmap=plt.cm.autumn, edgecolor='b', s=40)
plt.show()
# Out:
# /home/edward/.local/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/edward/.local/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# Простое и понятное объяснение, а также визуализацию результатов можно найти [здесь](https://distill.pub/2016/misread-tsne/).
#
# На самом деле, t-SNE случайным образом разбрасывает точки по пространству нужной размерности, а потом проводит оптимизацию функционала взаимодействия между точками. ([Видео с объяснениями](https://www.youtube.com/watch?v=NEaUSP4YerM))

# %% [markdown]
# #### Доморощенное видео, показывающее моделирование перемещения точек
#
# Берем куб, а потом тессеракт, бросаем их с разной точностью на плоскость, смотрим что получается, после того, как точки перестали перемещаться.

# %%
import manimlib as ma
from dataclasses import dataclass
import numpy as np
from seaborn import color_palette
# import re
# from pymorphy2 import MorphAnalyzer
# from collections import Counter

# %%
class UMAPSimulation:
    
    def __init__(self):
        self.dist_matrix = 0
        self.positions = 0
        self.point_count = 0
        self.step_no = 1
        
    # Генерация матрица расстояний для точек. 
    # По умолчанию точки расположены на расстоянии 1 друг от друга.
    def generate(self, pc):

        self.point_count = pc
        self.step_no = 1
        self.dist_matrix = np.ones((self.point_count, self.point_count))
        for i in range(self.point_count):
            self.dist_matrix[i,i] = 0 

        # Для части точек делаем случайное отклонение [-0.5; +0.5] от 1
        dif_pos = np.random.rand(3 * self.point_count, 2) * self.point_count
        dif_pos = dif_pos.astype(np.int32)
        for dp in dif_pos:
            n = np.random.rand(1) - 0.5
            self.dist_matrix[dp[0], dp[1]] += n
            self.dist_matrix[dp[1], dp[0]] += n

        # Сделаем три компоненты сильной связности, чтобы было видно как они стягиваются друг к другу.
        for k in [[0,5], [10,15], [20,25]]:
            for i in range(k[0], k[1]):
                for j in range(k[0], k[1]):
                    if i == j:
                        continue
                    n = np.random.rand(1) * 0.2
                    self.dist_matrix[i, j] = n
                    self.dist_matrix[j, i] = n

        # Для еще части увеличиваем расстояния.
        dif_pos = np.random.rand(3 * self.point_count, 2) * self.point_count
        dif_pos = dif_pos.astype(np.int32)
        for dp in dif_pos:
            n = np.random.standard_normal(1)[0] * 2
            self.dist_matrix[dp[0], dp[1]] += n
            self.dist_matrix[dp[1], dp[0]] += n

        # Могли получиться отрицательные расстояния.
        self.dist_matrix = np.absolute(self.dist_matrix)
        self.positions = np.random.rand(self.point_count, 2)
        
    def generate_cube(self):
        
        self.point_count = 8
        self.step_no = 1
        self.dist_matrix = np.zeros((self.point_count, self.point_count))
        self.dist_matrix[0, [1,2,4]] = 1
        self.dist_matrix[1, [0,3,5]] = 1
        self.dist_matrix[2, [0,3,6]] = 1
        self.dist_matrix[3, [1,2,7]] = 1
        self.dist_matrix[4, [0,5,6]] = 1
        self.dist_matrix[5, [1,4,7]] = 1
        self.dist_matrix[6, [2,4,7]] = 1
        self.dist_matrix[7, [3,5,6]] = 1
        self.positions = np.array([[0,1], [1,1], [0,0], [1,0], [0.5,1.5], [1.5,1.5], [0.5,0.5], [1.5,0.5]])

    def generate_tesseract(self):
        
        self.point_count = 16
        self.step_no = 1
        self.dist_matrix = np.zeros((self.point_count, self.point_count))
        self.dist_matrix[0, [1,2,4,8]] = 1
        self.dist_matrix[1, [0,3,5,9]] = 1
        self.dist_matrix[2, [0,3,6,10]] = 1
        self.dist_matrix[3, [1,2,7,11]] = 1
        self.dist_matrix[4, [0,5,6,12]] = 1
        self.dist_matrix[5, [1,4,7,13]] = 1
        self.dist_matrix[6, [2,4,7,14]] = 1
        self.dist_matrix[7, [3,5,6,15]] = 1
        self.dist_matrix[8, [9,10,12,0]] = 1
        self.dist_matrix[9, [8,11,13,1]] = 1
        self.dist_matrix[10, [8,11,14,2]] = 1
        self.dist_matrix[11, [9,10,15,3]] = 1
        self.dist_matrix[12, [8,13,14,4]] = 1
        self.dist_matrix[13, [9,12,15,5]] = 1
        self.dist_matrix[14, [10,12,15,8]] = 1
        self.dist_matrix[15, [11,13,14,7]] = 1
        self.positions = np.array([[0,1], [1,1], [0,0], [1,0], 
                                   [0.5,1.5], [1.5,1.5], [0.5,0.5], [1.5,0.5],
                                   [-2,0], [-1,0], [-2,-1], [-1,-1], 
                                   [-1.5,0.5], [-0.5,0.5], [-1.5,-0.5], [-0.5,-0.5]])
        
        
    def shake_figure(self):
        for i in range(len(self.positions)):
            self.positions[i][0] += 2 * np.random.rand(1)[0] - 1 
            self.positions[i][1] += 2 * np.random.rand(1)[0] - 1 
        

    # Расчет силы, действующей на две точки.
    def calcForce(self, pos1, pos2, dist):
        v1 = pos1 - pos2
        rel = np.linalg.norm(v1) / dist
        # Если (расстояние на плоскости) / (расстояние между точками в исходном пространстве) > 1
        # то притягиваются, в противном случае - отталкиваются.
        if rel > 1:
            return v1 * rel
        else:
            return -2 * v1 / rel

    # Рассчитываем вектора смещений для точек в зависимости от суммы сил,
    # действующих на каждую точку.
    def calcVectors(self):
        vectors = np.zeros((self.point_count, 2))
        for i in range(self.point_count):
            v = np.zeros(2)
            for j in range(self.point_count):
                if i == j:
                    continue
                v += self.calcForce(self.positions[j], self.positions[i], self.dist_matrix[i, j])

            vectors[i] += v
        # Шаг будем сокращать с течением времени.
        vectors = np.array(vectors) * 0.01 / np.cbrt(self.step_no+10)
        vectors[vectors>1] = 1
        return vectors

    # Здесь имитируем UMAP, добавляя силу, которая пытаетсяя разместить их на круге.
    # Не очень хорошо видна какая-либо разница.
    def calcVectors2(self):
        vectors = np.zeros((self.point_count, 2))
        # это расчет силы, отталкивающей точки от их центра масс.
        cx = sum([p[0] for p in self.positions]) / self.point_count
        cy = sum([p[1] for p in self.positions]) / self.point_count
        center = np.array([cx, cy])
        d = self.positions - center
        vectors = 100 * d / np.linalg.norm(d) ** 2

        # Это расчет вектора смещений точек.
        for j in range(self.point_count):
            n1 = self.positions - self.positions[j]
            n2 = np.linalg.norm(n1, axis=1) / self.dist_matrix[j]
            n3 = np.zeros((self.point_count, 2))
            for i, nn1 in enumerate(n1):
                if n2[i] > 1:
                    n3[i] += nn1 * n2[i]
                elif n2[i] <= 1 and n2[i] != 0:
                    n3[i] -= 2 * nn1 / (n2[i]+1e-6)
            vectors[j] += sum(n3)
        vectors *= 0.1 / np.cbrt(self.step_no+10)
        vectors[vectors>0.5] = 0.5
        return vectors

    # Эта функция не возвращает вектор смещений, а просто смещает точки.
    # Плюс, здесь сделан аналог далекий SGD - точка перемещается сразу после расчета вектора.
    def calcPositions(self):
        vectors = np.zeros((self.point_count, 2))
        for j in range(self.point_count):
            for m in range(5):
                n1 = self.positions - self.positions[j]
                n2 = np.linalg.norm(n1, axis=1) / self.dist_matrix[j]
                n2[(n2==np.inf)|(n2==-np.inf)|(n2!=n2)] = 0.9
                n3 = np.zeros((self.point_count, 2))
                for i, nn1 in enumerate(n1):
                    if n2[i] > 1:
                        n3[i] += nn1 * n2[i] 
                    elif n2[i] <= 1 and n2[i] != 0:
                        n3[i] -= 4 * n2[i] / nn1
                n3[n3==-np.inf] = 0
                v = sum(n3) * 0.01 / np.cbrt(self.step_no+10) + vectors[j]
                if any(v>0.1):
                    v /= max(v) * 3
                self.positions[j] += v
        return self.positions

    # Рассчитывает нове положения точек и отрисовывает.
    def moveAndDrawPoints(self):
        self.positions += self.calcVectors()
        self.step_no += 1

    # Рассчитывает нове положения точек и отрисовывает (для имитации UMAP).
    def moveAndDrawPoints2(self):
        self.positions = self.calcPositions()
        self.step_no += 1

# %%
def convert_colors(clr_in):
    clr_out = [int(c*256) for c in clr_in]
    clr_out = f"#{clr_out[0]:x}{clr_out[1]:x}{clr_out[2]:x}"
    return clr_out
    
class PointsSimulation(ma.Scene):

    def __init__(self):
        super().__init__()
        self.sequences = []
    
    def addDots(self, positions):
        
        anim = []
        plt = color_palette("crest", n_colors=256)

        pos_count = len(positions)
        dots = []
        remove_it = []
        for i, position in enumerate(positions):
            # !!! Что-то эта проверка не работает!!!
            to_add = -1
            if len(self.sequences) > 0:
                for j, dt in enumerate(self.sequences[0]):
                    if abs(dt.get_x() - position[0]) < 0.001 and \
                       abs(dt.get_y() == position[1]) < 0.001:
                        to_add = j
            if to_add == -1:
                dot = ma.Dot([position[0], position[1], 0], 
                             color=convert_colors(plt[int(256*i/pos_count)]))
                dots.append(dot)
                anim.append(ma.FadeIn(dot, run_time=0.2))
                self.add(dot)
            else:
                dots.append(self.sequences[0][to_add])
                self.sequences[0][to_add].set_opacity(0.8)
                del self.sequences[0][to_add]


        if len(self.sequences) >= 5:
            for dot in self.sequences[4]:
                remove_it.append(dot)
            self.sequences = self.sequences[:4]
        self.sequences.insert(0, dots)

        for i, dots in enumerate(self.sequences[4:1:-1]):
            for dot in dots:
                dot.set_opacity(0.2+0.2*i)
        
        self.play(*anim)

    def draw_cube(self, positions, connections):
        
        plt = color_palette("crest", n_colors=256)
        pos_count = len(positions)
#         anim = []
        dots = []
        for i, position in enumerate(positions):
            dot = ma.Dot([position[0], position[1], 0], 
                         color=convert_colors(plt[int(256*i/pos_count)]))
            dots.append(dot)
            self.add(dot)
            
        for i in range(len(connections)):
            for j in range(i+1, len(connections)):
                if connections[i][j] == 1:
                    line = ma.Line(positions[i], positions[j])
                    self.add(line)

    def animate_cubes(self, positions1, positions2):
        
        plt = color_palette("crest", n_colors=256)
        pos_count = len(positions1)
        anim = []
        for i, (position1, position2) in enumerate(zip(positions1, positions2)):
            dot = ma.Dot([position1[0], position1[1], 0], 
                         color=convert_colors(plt[int(256*i/pos_count)]))
            anim.append(ma.MoveAlongPath(dot, 
                                         ma.Line([position1[0], position1[1], 0], 
                                         [position2[0], position2[1], 0]), run_time=1))
            self.add(dot)
            
        self.play(*anim)

# %%
pt_sim = PointsSimulation()

# %%
sim0 = UMAPSimulation()
sim0.generate_cube()

np.random.seed(45)
sim = UMAPSimulation()
sim.generate_cube()
# sim.shake_figure()

np.random.seed(40)
sim2 = UMAPSimulation()
sim2.generate_cube()
sim2.shake_figure()

sim0.positions[:,1] -= 3
sim.positions[:,0] += 1
sim2.positions[:,0] += 3

# pt_sim = PointsSimulation()
pt_sim.draw_cube(sim0.positions, sim0.dist_matrix)
pt_sim.wait(0.1)
pt_sim.animate_cubes(sim0.positions, sim.positions)
pt_sim.draw_cube(sim.positions, sim.dist_matrix)
pt_sim.wait(1)
pt_sim.animate_cubes(sim0.positions, sim2.positions)
pt_sim.draw_cube(sim2.positions, sim2.dist_matrix)
pt_sim.wait(1)

# cube1_anim = pt_sim.draw_cube(sim.positions, sim.dist_matrix)
# cube2_anim = pt_sim.draw_cube(sim2.positions, sim2.dist_matrix)
# pt_sim.play(*cube0_anim, *cube1_anim, *cube2_anim)

for i in range(40):
    pt_sim.clear()
#     sim.moveAndDrawPoints()
#     sim.positions += sim.calcVectors2()
    sim.positions = sim.calcPositions()
    sim2.positions = sim2.calcPositions()
    cube0_anim = pt_sim.draw_cube(sim0.positions, sim0.dist_matrix)
    cube1_anim = pt_sim.draw_cube(sim.positions, sim.dist_matrix)
    cube2_anim = pt_sim.draw_cube(sim2.positions, sim2.dist_matrix)
#     pt_sim.addDots(sim.positions)
#     pt_sim.play(*cube0_anim, *cube1_anim, *cube2_anim)
    pt_sim.wait(0.2)
    
pt_sim.window.close()
# Out:
# /tmp/ipykernel_380463/330148154.py:158: RuntimeWarning: divide by zero encountered in true_divide
#   n2 = np.linalg.norm(n1, axis=1) / self.dist_matrix[j]
# /tmp/ipykernel_380463/330148154.py:158: RuntimeWarning: invalid value encountered in true_divide
#   n2 = np.linalg.norm(n1, axis=1) / self.dist_matrix[j]
# /tmp/ipykernel_380463/330148154.py:165: RuntimeWarning: divide by zero encountered in true_divide
#   n3[i] -= 4 * n2[i] / nn1

# %%
pt_sim = PointsSimulation()

# %%
sim0 = UMAPSimulation()
sim0.generate_tesseract()

np.random.seed(47)
sim = UMAPSimulation()
sim.generate_tesseract()
sim.shake_figure()

# np.random.seed(149)
# np.random.seed(156)
sim2 = UMAPSimulation()
sim2.generate_tesseract()
# sim2.shake_figure()

sim0.positions[:,1] -= 3
sim.positions[:,0] -= 3
sim2.positions[:,0] += 4

# pt_sim = PointsSimulation()
pt_sim.draw_cube(sim0.positions, sim0.dist_matrix)
pt_sim.wait(1)
pt_sim.animate_cubes(sim0.positions, sim.positions)
pt_sim.draw_cube(sim.positions, sim.dist_matrix)
pt_sim.wait(1)
pt_sim.animate_cubes(sim0.positions, sim2.positions)
pt_sim.draw_cube(sim2.positions, sim2.dist_matrix)
pt_sim.wait(1)

# cube1_anim = pt_sim.draw_cube(sim.positions, sim.dist_matrix)
# cube2_anim = pt_sim.draw_cube(sim2.positions, sim2.dist_matrix)
# pt_sim.play(*cube0_anim, *cube1_anim, *cube2_anim)

for i in range(40):
    pt_sim.clear()
#     sim.moveAndDrawPoints()
#     sim.positions += sim.calcVectors2()
    sim.positions = sim.calcPositions()
    sim2.positions = sim2.calcPositions()
    cube0_anim = pt_sim.draw_cube(sim0.positions, sim0.dist_matrix)
    cube1_anim = pt_sim.draw_cube(sim.positions, sim.dist_matrix)
    cube2_anim = pt_sim.draw_cube(sim2.positions, sim2.dist_matrix)
#     pt_sim.addDots(sim.positions)
#     pt_sim.play(*cube0_anim, *cube1_anim, *cube2_anim)
    pt_sim.wait(0.1)
    
pt_sim.window.close()
# Out:
# /tmp/ipykernel_380463/330148154.py:158: RuntimeWarning: divide by zero encountered in true_divide
#   n2 = np.linalg.norm(n1, axis=1) / self.dist_matrix[j]
# /tmp/ipykernel_380463/330148154.py:158: RuntimeWarning: invalid value encountered in true_divide
#   n2 = np.linalg.norm(n1, axis=1) / self.dist_matrix[j]
# /tmp/ipykernel_380463/330148154.py:165: RuntimeWarning: divide by zero encountered in true_divide
#   n3[i] -= 4 * n2[i] / nn1

# %% [markdown]
# #### Доморощенная демка, показывающая как проходит оптимизация точек в пространстве
#
# Ниже приводится моделирование расположения случайных точек, для которых известны их расстояния в многомерном пространстве. При генерации данных они случайным образом распологаются на плоскости. Далее алгоритм сдвигает их так, чтобы улучить взаимное расположение и сделать его более похожим на исходное.

# %%
# Этот код предназначен для того, чтобы посмотреть как движутся точки.
# Этот код не предназначен для того, чтобы в нем копаться с целью понять, как работать с t-SNE!!!

from model_springs import *
from ipywidgets import Button, interact, interactive_output, HBox, VBox, Layout, \
                       Output, FloatSlider, IntSlider, Checkbox, Select
from IPython.display import display

import numpy as np

# %%
# Глобальные переменные: номер шага, матрица расстояний в исходном пространстве, 
# позиции точек в двумерном пространстве, количество точек.
step_no = 1
dist_matrix = None
positions = None
point_count = 50

# %%
out = Output(layout=Layout(height='400px', width = '600px', border='solid'))
ax = plt.gca()

buttonGen = Button(description='Generate')
buttonStep = Button(description='Step')
vbox = VBox(children=(buttonGen, buttonStep,))
hbox = HBox(children=(out, vbox))
display(hbox)
with out:
    out.clear_output(wait=True)

buttonGen.on_click(generate)
buttonStep.on_click(moveAndDrawPoints2)

init_globals(dist_matrix, positions, point_count, step_no, ax, out)
generate(None)
for i in range(100):
    moveAndDrawPoints2(1)

# %% [markdown]
# ### Алгоритм UMAP
#
# Это самый свежий алгоритм, он появился в 2018 году - UMAP (<i>Uniform Manifold Approximation and Projection</i>). Принцип работы аналогичен t-SNE. Посмотрим и на его результаты.
#
# <b>Внимание!!!</b>
#
# Для установки используйте umap-learn (https://pypi.org/project/umap-learn/)<br>
# Его интерфейс отличается от библиотеки umap.
#
# `pip install umap-learn`

# %%
import umap

# %%
umap_emb = umap.UMAP()
show_reduced = umap_emb.fit_transform(blob_X)

fig, ax = plt.subplots()
ax.scatter(show_reduced[:, 0], show_reduced[:, 1], 
           cmap=plt.cm.autumn, edgecolor='b', s=40)
plt.show()

# %% [markdown]
# Теперь посмотрим что сделают эти преобразования с сеткой.

# %%
grid_coord = np.array(np.meshgrid(np.arange(10), np.arange(10), np.arange(10), np.arange(10))).T.reshape(-1,4)

# %% [markdown]
# Ниже специально приведены значения времени, которое потреовалось для расчета. Вы можете оценить, стоит ли запускать, или можно просто посмотреть на результат.

# %%
# %%time
show_reduced = PCA().fit_transform(grid_coord)

fig, ax = plt.subplots()
ax.scatter(show_reduced[:, 0], show_reduced[:, 1], 
           cmap=plt.cm.autumn, edgecolor='b', s=40)
plt.show()
# Out:
# CPU times: user 65.9 ms, sys: 32 µs, total: 65.9 ms
# Wall time: 65.8 ms

# %%
# %%time
show_reduced = tsne.fit_transform(grid_coord)

fig, ax = plt.subplots()
ax.scatter(show_reduced[:, 0], show_reduced[:, 1], 
           cmap=plt.cm.autumn, edgecolor='b', s=40)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# NameError: name 'tsne' is not defined

# %%
# %%time
show_reduced = umap_emb.fit_transform(grid_coord)

fig, ax = plt.subplots()
ax.scatter(show_reduced[:, 0], show_reduced[:, 1], 
           cmap=plt.cm.autumn, edgecolor='b', s=40)
plt.show()
# Out:
# CPU times: user 1min 8s, sys: 259 ms, total: 1min 8s
# Wall time: 20.4 s

# %% [markdown]
# Теперь посмотрим на классику - ирисы Фишера.

# %%
from sklearn.datasets import load_iris

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris, hue='species');

# %%
X = iris.iloc[:, :4].values

mapping = dict((s, i) for i, s in enumerate(iris.species.unique()))
y = iris.species.replace(mapping).values

X.shape
# Out:
# (150, 4)

# %%
# %matplotlib inline

from ipywidgets import interact, IntSlider

# %%
def umapped_irises(n, c, s):
    fig, ax = plt.subplots()

    umap_i = umap.UMAP(n_neighbors=n, local_connectivity=c, repulsion_strength=s, random_state=1234)
    umap_iris = umap_i.fit_transform(X)
    ax.scatter(umap_iris[:,0], umap_iris[:,1], c = y);
    plt.show()

# %%
#fig, ax = plt.subplots()

_=interact(umapped_irises, n=IntSlider(min=1, max=50, value=14, step=1), 
          c=IntSlider(min=1, max=10, value=1, step=1), s=IntSlider(min=1, max=10, value=1, step=1))
# Out:
# interactive(children=(IntSlider(value=14, description='n', max=50, min=1), IntSlider(value=1, description='c',…

# %% [markdown]
# Рассмотренные методы обладают следующими достоинствами и недостатками.
# - PCA
#     * быстрый (+);
#     * повторяющиеся результаты (+);
#     * можно добавить новые точки (+);
#     * строит проекцию, то есть часть данных теряется (-).
# - t-SNE и UMAP
#     * стараются сохранить расстояния между точками (+);
#     * это достигается за счет нелинейных искажений (+-);
#     * медленнее PCA (-);
#     * а текущий момент добавление новых точек возможно только для реализаций UMAP.

# %% [markdown]
# ## Немного чудес со снижением размерности пространства признаков

# %% [markdown]
# Посмотрим насколько применение UMAP может улучшить классификацию.
#
# Возьмем набор данных с рукописными цифрами. Каждая цифра представляет собой картинку 8х8 пикселей, то есть вектор из 64 элементов.

# %%
# Загружаем набор данных.
from sklearn.datasets import load_digits

digits = load_digits()

# %%
# Посмотрим на одну картинку.
img = digits.images
plt.imshow(img[0], cmap=plt.cm.Greys_r);

# %%
# Размер изображения. Само изображение хранится как массив numpy.
img[0].shape
# Out:
# (8, 8)

# %%
# Правращаем картинки в вектора.
X = img.reshape(-1, 64)

# %%
X.shape
# Out:
# (1797, 64)

# %%
# Отделим целевую переменную.
y = digits.target

# %%
# Преобразуем координаты при помощи проекции - PCA.
pca2d = PCA(n_components=2)
show_reduced = pca2d.fit_transform(X)

# %%
len(show_reduced)
# Out:
# 1797

# %% [markdown]
# Отобразиц полученные проекции. Каждой целевой переменной на графике соответствует свой цвет.

# %%
fig, ax = plt.subplots()
ax.scatter([x[0] for x in show_reduced], [x[1] for x in show_reduced], c=y,
           cmap=plt.cm.jet, s=4)
plt.show()

# %%
# Сделаем преобразование при помощи UMAP.
umap2d=umap.UMAP(n_components=2)
show_reduced = umap2d.fit_transform(X)

# %% [markdown]
# И, о чудо!, цифры разделились!

# %%
fig, ax = plt.subplots()
ax.scatter([x[0] for x in show_reduced], [x[1] for x in show_reduced], c=y,
           cmap=plt.cm.jet, s=4)
plt.show()

# %% [markdown]
# ### Некоторые выводы
#
# Рассмотренные методы позволяют проводить следующие действия:
# - визуализировать многомерные данные в ходе предварительного анализа, визуализация позволяет прийти к преварительным выводам о возмоности или невозможности применения разных методов анализа;
# - снизить размерность анализируемых данных и получить выигрыш в скорости обработки;
# - точность анализа после преобразования пространства может как снизиться, так и увеличиться в зависимости от природы данных;
# - методы t-SNE и UMAP позволяют работать с предварительно рассчитанными матрицами расстояниями между точками, за счет этого можно преобразовать неметрическое пространство в метрическое.

# %% [markdown]
# ## Снижение размерности пространства признаков для текстов

# %% [markdown]
# Теперь посмотрим каким образом мы можем отобразить векторизованные тексты при помощи новых методов.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
with open("data/lenta2018.txt", encoding="utf-8") as news_file: # Файл с новостями.
    text_news = [n.split("-----\n")[1] for n in news_file.read().split("=====\n")[1:]]

# %%
cvct = TfidfVectorizer(input = text_news[:10], 
                       token_pattern="[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+|[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+|[а-яёА-ЯЁ]+", 
                       ngram_range=(1, 2))

# %%
tfidf_res = cvct.fit_transform(text_news)

# %%
umap_text = umap.UMAP(n_components=2)
text_reduced = umap_text.fit_transform(tfidf_res)

# %%
fig, ax = plt.subplots()
ax.scatter(text_reduced[:, 0], text_reduced[:, 1], s=4)
plt.show()

# %%
center = np.array([-3, 8])
texts_group = [i for i, pt in enumerate(text_reduced) if np.linalg.norm(center-pt)<0.3]

# %%
[text_news[i][:100] for i in texts_group]
# Out:
# ['Основатель SpaceX и сооснователь Tesla Илон Маск решил переименовать свои огнеметы в «неогнеметы». О',
#  'В Японии запустили самую маленькую в мире ракету-носитель SS-520 весом всего в три тонны Об этом в с',
#  'Частная американская компания SpaceX выложила в сеть анимацию старта сверхтяжелой ракеты Falcon Heav',
#  'Глава американской компании SpaceX Илон Маск раскрыл планы на будущее сверхтяжелой ракеты-носителя F',
#  'SpaceX провела первый запуск сверхтяжелой ракеты-носителя Falcon Heavy. Трансляция велась на YouTube',
#  'SpaceX, запустившая сверхтяжелую ракету Falcon Heavy, организовала видеотрансляцию полета автомобиля',
#  'Центральный блок ракеты Falcon Heavy, запущенной компанией SpaceX с космодрома на мысе Канаверал, не',
#  'Социальные сети наводнили фотожабы с автомобилем Tesla, который SpaceX «ради смеха» выпустила в косм',
#  'В Омской области заключенные исправительной колонии №6 слепили из снега мобильную пусковую установку',
#  'SpaceX не будет предоставлять большие скидки на пуски использованных тяжелых носителей Falcon 9, соо',
#  'Исполнительный директор «Роскосмоса» по коммуникациям Игорь Буренков назвал запуск Falcon Heavy амер',
#  'Основатель компании SpaceX Илон Маск выложил последнее фото электромобиля Tesla, отправленного в кос',
#  'Новые российские плазменные двигатели СПД-140 для спутников прошли летные испытания, сообщил РИА Нов',
#  'Космическое командование ВВС США включило автомобиль Tesla Roadster, который был запущен в космос на',
#  'Нидерландский астроном Марко Лангбрук ночью 7 февраля 2018 сфотографировал в небе над Лейденом совет',
#  'Глава американской компании SpaceX Илон Маск назвал причину неудачных пусков сверхтяжелой ракеты Н-1',
#  'Автомобиль Tesla Roadster, который был запущен в космос на ракете Falcon Heavy, будет уничтожен в ре',
#  'ВВС США подорвали первую ступень Falcon 9, возвращавшуюся на Землю после запуска ракетой спутника св',
#  'SpaceX предлагала НАСА и ВВС США использовать первый пуск сверхтяжелой ракеты Falcon Heavy для беспл',
#  'Автомобиль Tesla Roadster, запущенный в космос на ракете Falcon Heavy, исчезнет из поля видимости зе',
#  'Основатель SpaceX Илон Маск объяснил причину падения основного разгонного блока Falcon Heavy. Об это']

# %%
umap_text3 = umap.UMAP(n_components=3)
text_reduced3 = umap_text3.fit_transform(tfidf_res)

# %%
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib notebook

# %%
fig = plt.figure(4, figsize=(8, 6))
ax = Axes3D(fig=fig, elev=60, azim=150, auto_add_to_figure=False)
fig.add_axes(ax)
ax.scatter(xs=text_reduced3[:, 0], 
           ys=text_reduced3[:, 1], 
           zs=text_reduced3[:, 2], 
           edgecolor='b', 
           s=4);
ax.set_xlabel('$X$');
ax.set_ylabel('$Y$');
ax.set_zlabel('$Z$');
# Out:
# <img src="data:image/png;base64,..." width="576">

# %%
center3 = np.array([-1., 6., 5.])
texts_group3 = [i for i, pt in enumerate(text_reduced3) if np.linalg.norm(center3-pt)<0.5]
[text_news[i][:100] for i in texts_group3]
# Out:
# []

# %%
umap_text3 = umap.UMAP(n_neighbors=15, n_components=3)
text_reduced3 = umap_text3.fit_transform(tfidf_res)

# %%
fig = plt.figure(5, figsize=(8, 6))
ax = Axes3D(fig=fig, elev=60, azim=150, auto_add_to_figure=False)
fig.add_axes(ax)
ax.scatter(xs=text_reduced3[:, 0], 
           ys=text_reduced3[:, 1], 
           zs=text_reduced3[:, 2], 
           edgecolor='b', 
           s=4);
ax.set_xlabel('$X$');
ax.set_ylabel('$Y$');
ax.set_zlabel('$Z$');
# Out:
# <img src="data:image/png;base64,..." width="576">

# %%
center3 = np.array([-1., 9., 5])
texts_group3 = [i for i, pt in enumerate(text_reduced3) if np.linalg.norm(center3-pt)<1]
[text_news[i][:100] for i in texts_group3]
# Out:
# ['Министерство юстиции США начало расследование фактов коррупции в Международном олимпийском комитете ',
#  'Тренеры Василий Карасев и Саша Обрадович определили стартовые пятерки команд «Звезд России» и «Звезд',
#  'Норвежский биатлонист Эмиль Хегле Свендсен пристыдил Международный олимпийский комитет (МОК) за отст',
#  'Российская теннисистка Дарья Касаткина обыграла первую ракетку мира датчанку Каролину Возняцки и выш',
#  'Нападающий клуба Национальной хоккейной лиги (НХЛ) «Питтсбург Пингвинс» Фил Кессел, проходящий проце',
#  'Более 60 тысяч человек побывали в субботу, 3 февраля, на концерте «Россия в моем сердце» в Москве. О',
#  'Суд Швейцарии отклонил иск шести российских спортсменов к Международному олимпийскому комитету (МОК)',
#  'Сборная России по хоккею с мячом (бенди) стала чемпионом мира. Об этом сообщает корреспондент «Ленты',
#  'Президент Международного олимпийского комитета (МОК) Томас Бах заявил, что вопрос о допуске оправдан',
#  'Международный олимпийский комитет (МОК) задумался об исключении бокса из программы Олимпийских игр 2',
#  'В сотнях допинг-проб лыжников, в разные годы выступавших на зимних Олимпийских играх, обнаружены ано',
#  'На открытии Игр в Пхенчхане флаг Международного олимпийского комитета (МОК), под которым выступят ро',
#  'Комиссия Международного олимпийского комитета (МОК) отказала в приглашении на Олимпиаду в Пхенчхане ',
#  'Офицеры Всемирного антидопингового агентства (WADA) сорвали тренировку женской сборной России по хок',
#  'Президент Международного олимпийского комитета (МОК) Томас Бах рассказал, что комиссия, решавшая воп',
#  'Решение Спортивного арбитражного суда (CAS) подтверждает необоснованность подозрений насчет российск',
#  'Российская команда по биатлону не примет участия в церемонии открытия Олимпийских игр 2018 года. Об ',
#  'Президент Международного олимпийского комитета (МОК) Томас Бах заявил, что российские спортсмены, ко',
#  'Российские лыжники не примут участия в церемонии открытия Олимпийских игр 2018 года. Об этом сообщае',
#  'Премьер-министр России Дмитрий Медведев назвал постыдным и аморальным решение комиссии Международног',
#  'Президент Международного олимпийского комитета (МОК) Томас Бах объяснил, почему оправданные Спортивн',
#  'В церемонии открытия Олимпийских игр в южнокорейском Пхенчхане примут участие 70-75 российских спорт',
#  'Национальный олимпийский комитет Германии обрадовался решению Международного олимпийского комитета (',
#  'Глава комиссии Международного олимпийского комитета (МОК) по допуску российских спортсменов на Игры ',
#  'В суд первой инстанции трибунала Лозанны с иском к Международному олимпийскому комитету (МОК) обрати',
#  'Николь Ховерц, член рабочей группы Международного олимпийского комитета (МОК), раскрыла условия снят',
#  '@hockey_se / TwitterМужская сборная России по хоккею прибыла на Олимпиаду в Южную Корею, где более 2',
#  'Российские спортсмены завоюют только девять медалей на Олимпийских играх в Пхенчхане. С таким прогно',
#  'Столичный ЦСКА дома обыграл подмосковные «Химки» в матче Единой лиги ВТБ. Об этом сообщает пресс-слу',
#  'Серебряный призер Олимпиады в Сочи конькобежка Ольга Фаткулина рассказала, что будет делать, если кт',
#  'Форвард петербургского баскетбольного клуба «Зенит» Сергей Карасев признан самым ценным игроком (MVP',
#  'Восьмикратный олимпийский чемпион и 20-кратный чемпион мира по биатлону Уле-Эйнар Бьорндален будет у',
#  'Активистка организации PETA («Люди за этичное обращение с животными») Эшли Фруно провела акцию проте',
#  'Британским спортсменам рекомендовано пропустить церемонию открытия зимних Олимпийских игр 2018 года ',
#  'Краснодарский «Локомотив-Кубань» уступил саратовскому «Автодору» в матче Единой лиги ВТБ. Об этом со',
#  'Конькобежцы Денис Юсков и Павел Кулижников, биатлонисты Ирина Старых и Александр Логинов, а также шо',
#  'Президент Международного олимпийского комитета (МОК) Томас Бах рассказал о необходимых условиях того',
#  'Хакерская группировка Fancy Bears опубликовала данные, согласно которым глава независимой комиссии В',
#  'Олимпийские атлеты из России керлингисты Александр Крушельницкий и Анастасия Брызгалова проиграли ам',
#  'Врач сборной Норвегии Мона Кьелдсберг объяснила, зачем команда взяла на Олимпийские игры 2018 года в',
#  'Генеральный секретарь Федерации бобслея России Сергей Пархоменко рассказал об условиях пребывания ол',
#  'Руководитель делегации олимпийских атлетов из России на Играх 2018 года Станислав Поздняков рассказа',
#  'Спортивный арбитражный суд (CAS) отказался рассматривать апелляции шести российских спортсменов и се',
#  'Болельщики сборной России, недовольные допинг-скандалом, в результате которого ряд отечественных спо',
#  'Лишившийся шансов поехать на Олимпиаду в Пхенчхан конькобежец Павел Кулижников прокомментировал отка',
#  'Российские керлингисты Александр Крушельницкий и Анастасия Брызгалова обыграли команду Норвегии в ди',
#  'Российские компании, ведомства и средства массовой информации запустили в соцсетях флешмоб в поддерж',
#  'Японский прыгун с трамплина Нориаки Касаи стал первым спортсменом, принявшим участие в восьми Олимпи',
#  'Немецкая скелетонистка Тина Херман выразила мнение, что Международный олимпийский комитет (МОК) не д',
#  'В Южной Корее стартовали продажи шапок в цветах российского триколора. Спортсмены из России смогут и',
#  'В Норильске состоялся благотворительный матч с участием команд легенд отечественного хоккея и городс',
#  'Рестораны южнокорейского Пхёнчхана, в котором проходит Олимпиада, отказались убирать из меню блюда и',
#  'Спортивный арбитражный суд не удовлетворил апелляции 45 российских спортсменов и двух тренеров на не',
#  'Российские керлингисты Александр Крушельницкий и Анастасия Брызгалова обыграли команду Финляндии в т',
#  'Всемирное антидопинговое агентство (WADA) одобрило решение Спортивного арбитражного суда (CAS), кото',
#  'Глава комиссии Международного олимпийского комитета (МОК) Николь Хевертц прокомментировала решение С',
#  'Джим Уолден, адвокат информатора Всемирного антидопингового агентства (WADA) Григория Родченкова, пр',
#  'Вице-премьер Виталий Мутко прокомментировал решение Спортивного арбитражного суда (CAS) не допустить',
#  'Решение Спортивного арбитражного суда (CAS), отклонившего апелляции 45 российских спортсменов и двух',
#  'В южнокорейском Пхенчхане начались XXIII Зимние Олимпийские игры. Об этом в пятницу, 9 февраля, сооб',
#  'Глава комитета Госдумы по физкультуре и спорту Михаил Дегтярев заявил, что после окончания Игр в Пхе',
#  'Член олимпийской сборной США Кэти Юлендер, выступающая в скелетоне, призналась, что ради участия в О',
#  'Олимпийский чемпион 2002 года Алексей Ягудин раскритиковал российского фигуриста Михаила Коляду за в',
#  'Фигурист Евгений Плющенко рассказал о послании главам Международного олимпийского комитета (МОК) и М',
#  'Президент Международного олимпийского комитета (МОК) Томас Бах угрожал Спортивному арбитражному суду',
#  'Шведская лыжница Шарлотт Калла завоевала первое золото на Олимпийских играх 2018 года в Пхенчхане. О',
#  'Спортивный арбитражный суд (CAS) опубликовал мотивировочную часть решения по 47 российским спортсмен',
#  'Российский шорт-трекист Семен Елистратов завоевал бронзовую медаль на дистанции 1500 метров на Олимп',
#  'Российские биатлонистки Татьяна Акимова и Ульяна Кайшева остались без медалей в спринте на Олимпиаде',
#  'Российский шорт-трекист Семен Елистратов, ставший бронзовым призером в дистанции на 1500 метров, пос',
#  'Американская биатлонистка Сюзан Данкли одобрила решение Международного олимпийского комитета (МОК) о',
#  'Спортивный журналист Джейсон Гэй оценил внешний вид российских спортсменов, принявших участие в цере',
#  'Шорт-трекист Тибо Фоконне, отбывший 18-месячную дисквалификацию за употребление допинга, ушел от отв',
#  'Четырехкратный олимпийский чемпион Александр Тихонов остался недоволен результатами российских биатл',
#  'Российские спортсмены, приехавшие на Олимпийские игры в Пхенчхан, «чистые», но бдительность терять н',
#  'Российская фигуристка Евгения Медведева установила новый мировой рекорд по набранным баллам за прока',
#  'Норвежский лыжник Симен Крюгер выиграл золотую медаль в скиатлоне на Олимпийских играх в Пхенчхане. ',
#  'Российский вратарь «Тампа-Бэй Лайтнинг» Андрей Василевский в матче регулярного чемпионата Национальн',
#  'Украинский спортсмен Андрей Мандзий выпал из саней во время первого заезда на Олимпийских играх в Пх',
#  'Российские биатлонисты Антон Бабиков и Матвей Елисеев остались без медалей в спринтерской гонке на О',
#  'Хоккейная команда «Олимпийских атлетов из России» потерпела поражение от сборной Канады в первом мат',
#  'Российский биатлонист Антон Бабиков прокомментировал выступление в спринте на Олимпийских играх в Пх',
#  'Российский саночник Семен Павличенко рассказал о конфликте между его личным тренером Эдуардом Бурмис',
#  'Олимпийский чемпион Игр-2018 в биатлоне немец Арнд Пайффер выступил против недопуска к Олимпиаде рос',
#  'Российская фигуристка Алина Загитова заняла первое место в произвольной программе командного турнира',
#  'Российские фигуристы завоевали серебряную медаль командного турнира на Олимпиаде в Пхенчхане. Они за',
#  'Четырехкратный олимпийский чемпион Александр Тихонов прокомментировал выступление российских биатлон',
#  'Российская фигуристка Евгения Медведева прокомментировала серебряную медаль, завоеванную вместе с па',
#  'Российский скелетонист Никита Трегубов рассказал, что американские и британские спортсмены на Олимпи',
#  'Выступающая за Словакию российская биатлонистка Анастасия Кузьмина завоевала серебряную медаль в гон',
#  'Олимпийский чемпион и заслуженный мастер спорта Алексей Ягудин высказался относительно критики амери',
#  'Обладатель серебряной медали Олимпиады 2002 года Илья Авербух посчитал критику американки Эшли Вагне',
#  'Французский биатлонист Мартен Фуркад после победы в гонке преследования высказался по поводу отсутст',
#  'Директор по коммуникациям Международного олимпийского комитета (МОК) Марк Адамс прокомментировал зая',
#  'Посетителей портала Reddit позабавил зритель, замеченный на Олимпиаде в Пхенчхане. Молодой человек н',
#  'Канадская фигуристка Меган Дюамель, участвующая в Олимпиаде-2018, спасла одну из корейских собак, вы',
#  'Шорт-трекист олимпийской сборной Японии Кэй Сайто провалил допинг-тест на Играх в Пхенчхане. Об этом',
#  'Керлингисты из России Анастасия Брызгалова и Александр Крушельницкий завоевали бронзу на Олимпийских',
#  'Российские керлингисты Анастасия Брызгалова и Александр Крушельницкий прокомментировали завоевание б',
#  'Международная ассоциация легкоатлетических федераций (IAAF) отклонила заявки трех российских спортсм',
#  'Российский биатлонист Антон Бабиков уклонился от общения с журналистами после гонки преследования на',
#  'Олимпийский атлет из России Павел Трихичев попал в больницу после падения в скоростном спуске в рамк',
#  '@EurosportSuomi / TwitterПоявилось видео падения россиянина Павла Трихичева на скоростном спуске в р',
#  'Двукратный олимпийский чемпион Максим Траньков подверг критике выступление российского фигуриста Мих',
#  'Украинская биатлонистка Валентина Семеренко, занявшая до этого 46-е место в спринте, не стартовала в',
#  'Специалисты по кибербезопасности подозревают русских хакеров во взломе системы интернета Олимпийских',
#  'Российская керлингистка Анастасия Брызгалова, завоевавшая бронзовую медаль Олимпиады в Пхенчхане в д',
#  'Российская лыжница Юлия Белорукова завоевала бронзовую медаль в спринте на Олимпийских играх в Пхенч',
#  'Российский лыжник Александр Большунов стал бронзовым призером Олимпийских игр в Пхенчхане. Об этом с',
#  'Российские хоккеистки проиграли сборной США в матче группового этапа Олимпийских игр в Пхенчхане. Об',
#  'Нападающий сборной России Илья Ковальчук побывал на матче российских и канадских хоккеисток в рамках',
#  'Тренер сборной США помог российскому лыжнику Алексею Виценко, упавшему в четвертьфинале лыжного спри',
#  'Экипировщик российской сборной на Олимпиаде в Пхенчхане — компания Zasport — выпустила лимитированну',
#  'Швейцарский горнолыжник Фабиан Бош продемонстрировал умение оригинально подниматься по эскалатору. В',
#  'Американская саночница Эмили Суини во время четвертого заезда на Олимпиаде в Пхенчхане выпала из сан',
#  'Конькобежец Сергей Грязцов и бобслеист Дмитрий Попов пропускают Олимпиаду-2018 из-за ошибки Междунар',
#  'В Южно-Сахалинске сочетались браком скелетонистка Ольга Потылицына и фристайлист Семен Денщиков. Об ',
#  'Голландский конькобежец Кьелд Нейс, ставший олимпийским чемпионом Пхенчхана на дистанции 1500 метров',
#  'Комиссия Международного олимпийского комитета (МОК) имела достаточно оснований для того, чтобы не вы',
#  'Двукратная олимпийская чемпионка по прыжкам с шестом Елена Исинбаева во второй раз стала мамой. Об э',
#  'Российский конькобежец Сергей Грязцов, которого по ошибке не допустили к Олимпийским играм в Пхенчха',
#  'В Пхенчхане, где проходят Олимпийские игры, начался ураган. Об этом в среду, 14 февраля, с места соб',
#  'Российский нападающий клуба Национальной хоккейной лиги (НХЛ) «Вашингтон Кэпиталс» Александр Овечкин',
#  'Двукратный олимпийский чемпион, сноубордист Вик Уайлд рассказал о жизни в России. Слова спортсмена п',
#  'Трехкратная олимпийская чемпионка, советская и российская лыжница Анфиса Резцова прокомментировала в',
#  'Президент Международного олимпийского комитета (МОК) Томас Бах провел встречу с представителями росс',
#  'В соцсетях обсуждают нездоровый аппетит чемпионки Олимпийских игр в Пхенчхане Хлои Ким (Chloe Kim). ',
#  'Сборная России по хоккею проиграла словакам в матче первого тура группового этапа на Олимпийских игр',
#  'Нападающий сборной России Илья Ковальчук прокомментировал поражение от сборной Словакии в стартовом ',
#  'Шведский биатлонист Себастьян Самуэльссон, завоевавший серебро в гонке преследования на Олимпийских ',
#  'Саночник Семен Павличенко, выступающий на Олимпиаде в Пхенчхане, рассказал, что руководство российск']
